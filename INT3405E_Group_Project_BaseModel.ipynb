# %% [markdown]
# <a href="https://colab.research.google.com/github/stereofantasy/Twini-Golf/blob/main/INT3405E_Group_Project_BaseModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
import numpy as np
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader

import cv2
import os
from nltk import wordpunct_tokenize
import re

# %%
# !gdown 1hUqu1mbFeTEfBvl-7fc56fHFfCSzIktD
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1hUqu1mbFeTEfBvl-7fc56fHFfCSzIktD
# To: /content/ml1m.zip
# 100% 105M/105M [00:00<00:00, 170MB/s]

# %%
# !unzip -qq ml1m.zip -d ml1m
# Out:
# Archive:  ml1m.zip
#    creating: ml1m/content/dataset/
#   inflating: ml1m/content/dataset/movies_test.dat
#   inflating: ml1m/content/dataset/users.dat
#   inflating: ml1m/content/dataset/genres.txt
#   inflating: ml1m/content/dataset/ratings.dat
#   inflating: ml1m/content/dataset/movies_train.dat
#    creating: ml1m/content/dataset/ml1m-images/
#   inflating: ml1m/content/dataset/ml1m-images/2816.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1043.jpg
#   inflating: ml1m/content/dataset/ml1m-images/941.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2.jpg
#   inflating: ml1m/content/dataset/ml1m-images/160.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1201.jpg
#   inflating: ml1m/content/dataset/ml1m-images/276.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2119.jpg
#   inflating: ml1m/content/dataset/ml1m-images/599.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2829.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3628.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1867.jpg
#   inflating: ml1m/content/dataset/ml1m-images/924.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2380.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1458.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3169.jpg
#   inflating: ml1m/content/dataset/ml1m-images/168.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1083.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2637.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3070.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2514.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1962.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2792.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2558.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3786.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1055.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1834.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3343.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2974.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1066.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3796.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1332.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3360.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1221.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1970.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2706.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1341.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1817.jpg
#   inflating: ml1m/content/dataset/ml1m-images/265.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2325.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1821.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2639.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3807.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1346.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2083.jpg
#   inflating: ml1m/content/dataset/ml1m-images/113.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2868.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3617.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2904.jpg
#   inflating: ml1m/content/dataset/ml1m-images/73.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3950.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3587.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2005.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1044.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1385.jpg
#   inflating: ml1m/content/dataset/ml1m-images/26.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1449.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3213.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2988.jpg
#   inflating: ml1m/content/dataset/ml1m-images/82.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2667.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2451.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2985.jpg
#   inflating: ml1m/content/dataset/ml1m-images/252.jpg
#   inflating: ml1m/content/dataset/ml1m-images/333.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1565.jpg
#   inflating: ml1m/content/dataset/ml1m-images/850.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2147.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1020.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2649.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3915.jpg
#   inflating: ml1m/content/dataset/ml1m-images/571.jpg
#   inflating: ml1m/content/dataset/ml1m-images/463.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1383.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1014.jpg
#   inflating: ml1m/content/dataset/ml1m-images/939.jpg
#   inflating: ml1m/content/dataset/ml1m-images/22.jpg
#   inflating: ml1m/content/dataset/ml1m-images/307.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2010.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3688.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1722.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2482.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2827.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3368.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2535.jpg
#   inflating: ml1m/content/dataset/ml1m-images/961.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2677.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2628.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1387.jpg
#   inflating: ml1m/content/dataset/ml1m-images/824.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2365.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3614.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3882.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2728.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2625.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1374.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1285.jpg
#   inflating: ml1m/content/dataset/ml1m-images/193.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3518.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3045.jpg
#   inflating: ml1m/content/dataset/ml1m-images/498.jpg
#   inflating: ml1m/content/dataset/ml1m-images/16.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2491.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3643.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2407.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2773.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3923.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3335.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2732.jpg
#   inflating: ml1m/content/dataset/ml1m-images/378.jpg
#   inflating: ml1m/content/dataset/ml1m-images/196.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1269.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1608.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2411.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3387.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2807.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2171.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2403.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1758.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2735.jpg
#   inflating: ml1m/content/dataset/ml1m-images/
jpg
#   inflating: ml1m/content/dataset/ml1m-images/1810.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3258.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3822.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3013.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1626.jpg
#   inflating: ml1m/content/dataset/ml1m-images/986.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3399.jpg
#   inflating: ml1m/content/dataset/ml1m-images/300.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3758.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1262.jpg
#   inflating: ml1m/content/dataset/ml1m-images/917.jpg
#   inflating: ml1m/content/dataset/ml1m-images/946.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3736.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1580.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2412.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3426.jpg
#   inflating: ml1m/content/dataset/ml1m-images/745.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1934.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3432.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2924.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2779.jpg
#   inflating: ml1m/content/dataset/ml1m-images/242.jpg
#   inflating: ml1m/content/dataset/ml1m-images/293.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2067.jpg
#   inflating: ml1m/content/dataset/ml1m-images/393.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1564.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3141.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1674.jpg
#   inflating: ml1m/content/dataset/ml1m-images/24.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2052.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1080.jpg
#   inflating: ml1m/content/dataset/ml1m-images/638.jpg
#   inflating: ml1m/content/dataset/ml1m-images/60.jpg
#   inflating: ml1m/content/dataset/ml1m-images/710.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3239.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1875.jpg
#   inflating: ml1m/content/dataset/ml1m-images/336.jpg
#   inflating: ml1m/content/dataset/ml1m-images/212.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1814.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2620.jpg
#   inflating: ml1m/content/dataset/ml1m-images/249.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2447.jpg
#   inflating: ml1m/content/dataset/ml1m-images/761.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3301.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3208.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3540.jpg
#   inflating: ml1m/content/dataset/ml1m-images/920.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2292.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2097.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1441.jpg
#   inflating: ml1m/content/dataset/ml1m-images/434.jpg
#   inflating: ml1m/content/dataset/ml1m-images/806.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1550.jpg
#   inflating: ml1m/content/dataset/ml1m-images/512.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2943.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2841.jpg
#   inflating: ml1m/content/dataset/ml1m-images/645.jpg
#   inflating: ml1m/content/dataset/ml1m-images/462.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3577.jpg
#   inflating: ml1m/content/dataset/ml1m-images/3326.jpg
#   inflating: ml1m/content/dataset/ml1m-images/1241.jpg
#   inflating: ml1m/content/dataset/ml1m-images/2191.jpg

# %%
# You need extract file ml1m.zip to folder ml1m before run code

users = pandas.read_csv('ml1m/content/dataset/users.dat', sep='::',
                        engine='python',
                        names=['userid', 'gender', 'age', 'occupation', 'zip']).set_index('userid')
ratings = pandas.read_csv('ml1m/content/dataset/ratings.dat', engine='python',
                          sep='::', names=['userid', 'movieid', 'rating', 'timestamp'])
movies_train = pandas.read_csv('ml1m/content/dataset/movies_train.dat', engine='python',
                         sep='::', names=['movieid', 'title', 'genre'], encoding='latin-1', index_col=False).set_index('movieid')
movies_test = pandas.read_csv('ml1m/content/dataset/movies_test.dat', engine='python',
                         sep='::', names=['movieid', 'title', 'genre'], encoding='latin-1', index_col=False).set_index('movieid')
movies_train['genre'] = movies_train.genre.str.split('|')
movies_test['genre'] = movies_test.genre.str.split('|')

users.age = users.age.astype('category')
users.gender = users.gender.astype('category')
users.occupation = users.occupation.astype('category')
ratings.movieid = ratings.movieid.astype('category')
ratings.userid = ratings.userid.astype('category')

# %%
movies_train
# Out:
#                                 title  \
# movieid
# 1650         Washington Square (1997)
# 185                   Net, The (1995)
# 1377            Batman Returns (1992)
# 3204     Boys from Brazil, The (1978)
# 1901                Dear Jesse (1997)
# ...                               ...
# 2539              Analyze This (1999)
# 3038      Face in the Crowd, A (1957)
# 1832          Heaven's Burning (1997)
# 657                Yankee Zulu (1994)
# 1750                  Star Kid (1997)
#
#                                             genre
# movieid
# 1650                                      [Drama]
# 185                            [Sci-Fi, Thriller]
# 1377           [Action, Adventure, Comedy, Crime]
# 3204                                   [Thriller]
# 1901                                [Documentary]
# ...                                           ...
# 2539                                     [Comedy]
# 3038                                      [Drama]
# 1832                              [Action, Drama]
# 657                               [Comedy, Drama]
# 1750     [Adventure, Children's, Fantasy, Sci-Fi]
#
# [3106 rows x 2 columns]

# %% [markdown]
# ## Dataset + Dataloader

# %%
# movies_train = pandas.read_csv('ml1m/dataset/movies_train.dat', engine='python',
#                          sep='::', names=['movieid', 'title', 'genre'], encoding='latin-1', index_col=False).set_index('movieid')

folder_img_path = 'ml1m/content/dataset/ml1m-images'
movies_train['id'] = movies_train.index
movies_train.reset_index(inplace=True)
movies_train['img_path'] = movies_train.apply(lambda row: os.path.join(folder_img_path, f'{row.id}.jpg'), axis = 1)
movies_train
# Out:
#       movieid                         title  \
# 0        1650      Washington Square (1997)
# 1         185               Net, The (1995)
# 2        1377         Batman Returns (1992)
# 3        3204  Boys from Brazil, The (1978)
# 4        1901             Dear Jesse (1997)
# ...       ...                           ...
# 3101     2539           Analyze This (1999)
# 3102     3038   Face in the Crowd, A (1957)
# 3103     1832       Heaven's Burning (1997)
# 3104      657            Yankee Zulu (1994)
# 3105     1750               Star Kid (1997)
#
#                                          genre    id  \
# 0                                      [Drama]  1650
# 1                           [Sci-Fi, Thriller]   185
# 2           [Action, Adventure, Comedy, Crime]  1377
# 3                                   [Thriller]  3204
# 4                                [Documentary]  1901
# ...                                        ...   ...
# 3101                                  [Comedy]  2539
# 3102                                   [Drama]  3038
# 3103                           [Action, Drama]  1832
# 3104                           [Comedy, Drama]   657
# 3105  [Adventure, Children's, Fantasy, Sci-Fi]  1750
#
#                                        img_path
# 0     ml1m/content/dataset/ml1m-images/1650.jpg
# 1      ml1m/content/dataset/ml1m-images/185.jpg
# 2     ml1m/content/dataset/ml1m-images/1377.jpg
# 3     ml1m/content/dataset/ml1m-images/3204.jpg
# 4     ml1m/content/dataset/ml1m-images/1901.jpg
# ...                                         ...
# 3101  ml1m/content/dataset/ml1m-images/2539.jpg
# 3102  ml1m/content/dataset/ml1m-images/3038.jpg
# 3103  ml1m/content/dataset/ml1m-images/1832.jpg
# 3104   ml1m/content/dataset/ml1m-images/657.jpg
# 3105  ml1m/content/dataset/ml1m-images/1750.jpg
#
# [3106 rows x 5 columns]

# %%
folder_img_path = 'ml1m/content/dataset/ml1m-images'
movies_test['id'] = movies_test.index
movies_test.reset_index(inplace=True)
movies_test['img_path'] = movies_test.apply(lambda row: os.path.join(folder_img_path, f'{row.id}.jpg'), axis = 1)
movies_test
# Out:
#      movieid                                       title  \
# 0       3397              Great Muppet Caper, The (1981)
# 1       2067                       Doctor Zhivago (1965)
# 2       2651      Frankenstein Meets the Wolf Man (1943)
# 3       2989                   For Your Eyes Only (1981)
# 4       3415                Mirror, The (Zerkalo) (1975)
# ..       ...                                         ...
# 772     2309  Inheritors, The (Die Siebtelbauern) (1998)
# 773     2421             Karate Kid, Part II, The (1986)
# 774     3255               League of Their Own, A (1992)
# 775      974                              Algiers (1938)
# 776     2555                        Baby Geniuses (1999)
#
#                           genre    id  \
# 0          [Children's, Comedy]  3397
# 1         [Drama, Romance, War]  2067
# 2                      [Horror]  2651
# 3                      [Action]  2989
# 4                       [Drama]  3415
# ..                          ...   ...
# 772                     [Drama]  2309
# 773  [Action, Adventure, Drama]  2421
# 774             [Comedy, Drama]  3255
# 775            [Drama, Romance]   974
# 776                    [Comedy]  2555
#
#                                       img_path
# 0    ml1m/content/dataset/ml1m-images/3397.jpg
# 1    ml1m/content/dataset/ml1m-images/2067.jpg
# 2    ml1m/content/dataset/ml1m-images/2651.jpg
# 3    ml1m/content/dataset/ml1m-images/2989.jpg
# 4    ml1m/content/dataset/ml1m-images/3415.jpg
# ..                                         ...
# 772  ml1m/content/dataset/ml1m-images/2309.jpg
# 773  ml1m/content/dataset/ml1m-images/2421.jpg
# 774  ml1m/content/dataset/ml1m-images/3255.jpg
# 775   ml1m/content/dataset/ml1m-images/974.jpg
# 776  ml1m/content/dataset/ml1m-images/2555.jpg
#
# [777 rows x 5 columns]

# %%
def tokenize(text):
    text = re.sub(r'[^\w\s]', '', text)
    text = text.lower()
    tokens = wordpunct_tokenize(text)
    tokens = tokens[:-1] # remove last token because it is the year which maybe is not useful
    return tokens

def create_vocab():
    df = movies_train.copy()
    arr_title = df['title'].tolist()
    vocab = set()
    for title in arr_title:
        tokens = tokenize(title)
        vocab.update(tokens)
    vocab = list(vocab)
    pad_token = '<PAD>'
    unk_token = '<UNK>'
    vocab.append(pad_token)
    vocab.append(unk_token)
    return vocab

# %%
class MLDataset(Dataset):
    def __init__(self, is_train=True):
        if is_train:
            self.data =  movies_train
        else:
            self.data = movies_test
        self.data['title_tokens'] = [tokenize(x) for x in self.data.title]

        # create vocab
        vocab = create_vocab()
        pad_token = '<PAD>'
        unk_token = '<UNK>'
        self.token2idx = {token: idx for idx, token in enumerate(vocab)}

        # Create a binary vector for each word in each sentence
        MAX_LENGTH = 7
        vectors = []
        for title_tokens in self.data.title_tokens.tolist():
            if len(title_tokens) < MAX_LENGTH:
                num_pad = MAX_LENGTH - len(title_tokens)
                for idx in range(num_pad):
                    title_tokens.append(pad_token)
            else:
                title_tokens = title_tokens[:MAX_LENGTH]
            title_vectors = []
            for word in title_tokens:
                binary_vector = np.zeros(len(vocab))
                if word in vocab:
                    binary_vector[self.token2idx[word]] = 1
                else:
                    binary_vector[self.token2idx[unk_token]] = 1
                title_vectors.append(binary_vector)

            vectors.append(np.array(title_vectors))
        self.data['vectors'] = vectors

        # label genre
        with open('ml1m/content/dataset/genres.txt', 'r') as f:
            genre_all = f.readlines()
            genre_all = [x.replace('\n','') for x in genre_all]
        self.genre2idx = {genre:idx for idx, genre in enumerate(genre_all)}

    def __getitem__(self, index):
        title = self.data.iloc[index].title
        img_path = self.data.iloc[index].img_path
        genre = self.data.iloc[index].genre

        # preprocess text
        title_vector = self.data.iloc[index].vectors
        title_tensor = torch.from_numpy(title_vector).float()

        # preprocess img
        if os.path.exists(img_path):
            img = cv2.imread(img_path)
        else:
            img = np.random.rand(256,256,3)
        img = cv2.resize(img, (256,256))
        img_tensor = torch.from_numpy(img.transpose(2,0,1)).float()

        # preprocess label
        genre_vector = np.zeros(len(self.genre2idx))

        for g in genre:
            genre_vector[self.genre2idx[g]] = 1
        genre_tensor = torch.from_numpy(genre_vector).float()

        return title_tensor, img_tensor, genre_tensor

    def __len__(self):
        return len(self.data)

# %%
train_set = MLDataset(is_train=True)
test_set = MLDataset(is_train=False)

BATCH_SIZE = 8
train_dataloader = DataLoader(train_set, batch_size=BATCH_SIZE)
test_dataloader = DataLoader(test_set, batch_size=BATCH_SIZE)

# %%
for title_tensor, img_tensor, genre_tensor in train_dataloader:
    print(title_tensor.shape, img_tensor.shape, genre_tensor.shape)
    break
for title_tensor, img_tensor, genre_tensor in test_dataloader:
    print(title_tensor.shape, img_tensor.shape, genre_tensor.shape)
    break
# Out:
# torch.Size([8, 7, 3899]) torch.Size([8, 3, 256, 256]) torch.Size([8, 18])
# torch.Size([8, 7, 3899]) torch.Size([8, 3, 256, 256]) torch.Size([8, 18])

# %% [markdown]
# ## Model

# %%
with open('ml1m/content/dataset/genres.txt', 'r') as f:
    genre_all = f.readlines()
num_classes = len(genre_all)
num_classes
# Out:
# 18

# %%
class BaseModel(nn.Module):
    def __init__(self, num_classes, len_vocab, embedding_dimension=3898, hidden_size=64):
        super(BaseModel, self).__init__()
        self.hidden_size = hidden_size

        # img
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
        self.maxpool = nn.MaxPool2d(kernel_size=4, stride=4)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(32 * 64 * 64, hidden_size)


        # text
        self.fc2 = nn.Linear(7*len_vocab, hidden_size)

        self.fc3 = nn.Linear(hidden_size*2, num_classes)

    def forward(self, text_tens, img_tens):
        text_feat = self.fc2(self.flatten(text_tens))

        img_feat = self.conv1(img_tensor)
        img_feat = self.maxpool(img_feat)
        img_feat = self.conv2(img_feat)
        img_feat = self.fc1(self.flatten(img_feat))

        out = self.fc3(torch.concat([text_feat, img_feat], dim=1))
        return out

# %%
vocab = create_vocab()
model = BaseModel(num_classes, len(vocab))

out = model(title_tensor, img_tensor)
out.shape
# Out:
# torch.Size([8, 18])

# %% [markdown]
# ## Loss

# %%
from torch import optim
criterion = nn.CrossEntropyLoss()

learning_rate = 1e-3
optimizer = optim.Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=learning_rate,
)

# %% [markdown]
# ## Training

# %%
device = torch.device('cuda:0')
NUM_EP = 10
model.to(device)
for ep in range(NUM_EP):
    print('ep:', ep)
    for idx, (title_tensor, img_tensor, genre_tensor) in enumerate(train_dataloader):
        title_tensor = title_tensor.to(device)
        img_tensor = img_tensor.to(device)
        genre_tensor = genre_tensor.to(device)

        out = model(title_tensor, img_tensor)

        loss = criterion(out, genre_tensor)

        loss.backward()
        optimizer.zero_grad()
        optimizer.step()
# Out:
# ep: 0
# ep: 1
# ep: 2
# ep: 3
# ep: 4
# ep: 5
# ep: 6
# ep: 7
# ep: 8
# ep: 9

# %%
# !pip install -q torchmetrics
from torchmetrics.classification import MultilabelF1Score

# %%
N, C = genre_tensor.shape

auroc_all = 0
f1_all = 0
f1 = MultilabelF1Score(num_labels=C, threshold=0.5, average='macro')
f1 = f1.to(device)
for title_tensor, img_tensor, genre_tensor in test_dataloader:
    title_tensor = title_tensor.to(device)
    img_tensor = img_tensor.to(device)
    genre_tensor = genre_tensor.to(device)

    out = model(title_tensor, img_tensor)
    f1_batch = f1(out, genre_tensor)
    f1_all += f1_batch

print('F1: ', f1_all/len(test_dataloader))
# Out:
# F1:  tensor(0.0942, device='cuda:0')
